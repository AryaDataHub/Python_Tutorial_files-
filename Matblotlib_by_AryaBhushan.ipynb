# %% [markdown]
# ![matplotlib](https://miro.medium.com/v2/resize:fit:750/format:webp/1*gw2NcnIYpiBlFy4le3pF5w.png)

# %% [markdown]
# # ***By Arya Bhushan***

# %% [markdown]
# **Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:**

# %%
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
print(matplotlib.__version__)    # To check the version of Matplotlib
# Out:
# 3.9.2

# %% [markdown]
# ## **Matplotlib Pyplot**

# %% [markdown]
# **Draw a line in a diagram from position (0,0) to position (20,50):**

# %%
xcord = np.array([0,20])
ycord = np.array([0,50])
plt.plot(xcord,ycord)
plt.show()

# %% [markdown]
# **Draw a line in a diagram from position (5, 10) to position (25, 30):**

# %%
xcord_ = np.array([5,25])
ycord_ = np.array([10,30])
plt.plot(xcord_,ycord_)
plt.show()

# %% [markdown]
# **Draw two points (without lines) in the diagram, one at position (5, 10) and one in position (25, 50):**

# %%
x_cord = np.array([5,25])
y_cord = np.array([10,50])
plt.plot(x_cord, y_cord, "o")   #To plot only the markers, use shortcut string notation parameter 'o', which means 'rings'.
plt.show()

# %% [markdown]
# **Draw a line in a diagram from position (6, 3) to (2, 5) then to (5, 7) and finally to position (7, 8):**

# %%
x_coord = np.array([6,2,5,7])
y_coord = np.array([3,5,7,8])
plt.plot(x_coord, y_coord)
plt.show()

# %% [markdown]
# **Plotting without x-points:**

# %%
ycoordi = np.array([2,5,7,9,8,11,15])
plt.plot(ycoordi)    
#If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc., depending on the length of the y-points.
plt.show()

# %% [markdown]
# ## **Matplotlib Markers**
# We can use the keyword argument **marker** to emphasize each point with a specified marker:

# %% [markdown]
# **Mark each point with a circle(o): (2,3),(4,5),(8,11),(12,14)**

# %%
xcoord = np.array([2,4,8,12])
ycoord = np.array([3,5,11,14])
plt.plot(xcoord, ycoord, marker = "o")
plt.show()

# %% [markdown]
# **Mark each point with a star(*): (2,3),(4,5),(8,11),(12,14)**

# %%
xcoord_ = np.array([2,4,8,12])
ycoord_ = np.array([3,5,11,14])
plt.plot(xcoord, ycoord, marker = "*")
plt.show()

# %% [markdown]
# ### **Marker Reference**
# - 'o'	Circle
# - '*'	Star
# - '.'	Point
# - ','	Pixel
# - 'x'	X
# - 'X'	X (filled)
# - '+'	Plus
# - 'P'	Plus (filled)
# - 's'	Square
# - 'D'	Diamond
# - 'd'	Diamond (thin)
# - 'p'	Pentagon
# - 'H'	Hexagon
# - 'h'	Hexagon
# - 'v'	Triangle Down
# - '^'	Triangle Up
# - '<'	Triangle Left
# - '>'	Triangle Right
# - '1'	Tri Down
# - '2'	Tri Up
# - '3'	Tri Left
# - '4'	Tri Right
# - '|'	Vline
# - '_'	Hline

# %% [markdown]
# ### **Line Reference**
#
# - '-'	Solid line
# - ':'	Dotted line
# - '--' Dashed line
# - '-.' Dashed/dotted line

# %% [markdown]
# ### **Color Reference**
# - 'r'	Red
# - 'g'	Green
# - 'b'	Blue
# - 'c'	Cyan
# - 'm'	Magenta
# - 'y'	Yellow
# - 'k'	Black
# - 'w'	White

# %% [markdown]
# ### **Format Strings fmt**
# - You can also use the shortcut string notation parameter to specify the marker.
#
# - This parameter is also called **fmt**, and is written with this syntax:
#
# - *marker|line|color*

# %% [markdown]
# **Mark each point with a circle, use dashed line and color should be red.**

# %%
xa = np.array([3,7,10,13])
ya = np.array([5,8,15,9])
plt.plot(xa, ya, "o--r")
plt.show()

# %% [markdown]
# ### **Marker Size**
# You can use the keyword argument **markersize** or the shorter version, **ms** to set the size of the markers

# %% [markdown]
# **Draw a line in a diagram from position (6, 3) to (2, 5) then to (5, 7) and finally to position (7, 8) and set the size of the markers to 14:**

# %%
xb = np.array([6,2,5,7])
yb = np.array([3,5,7,8])
plt.plot(xb, yb, marker = 'D', ms = 15)
plt.show()

# %% [markdown]
# ### **Marker Color**
# You can use the keyword argument **markeredgecolor** or the shorter **mec** to set the color of the edge of the markers:

# %% [markdown]
# **Draw a line in a diagram from position (6, 3) to (2, 5) then to (5, 7) and finally to position (7, 8), set the size of the markers to 20 and Set the EDGE color to red:**

# %%
xc = np.array([6,2,5,7])
yc = np.array([3,5,7,8])
plt.plot(xc, yc, marker = 'H', ms = 20, mec = 'r' )
plt.show()

# %% [markdown]
# We can use the keyword argument **markerfacecolor** or the shorter **mfc** to set the color inside the edge of the markers**

# %% [markdown]
# **Draw a line in a diagram from position (6, 3) to (2, 5) then to (5, 7) and finally to position (7, 8), set the size of the markers to 15,Set the color of both the edge Cyan and the face to Magenta:**

# %%
xd = np.array([6,2,5,7])
yd = np.array([3,5,7,8])
plt.plot(xd, yd, marker = 'P',ms = 15, mec = 'c', mfc = 'm')
plt.show()

# %% [markdown]
# **We can also use Hexadecimal color values:**

# %% [markdown]
# **Draw a line in a diagram from position (6, 3) to (2, 5) then to (5, 7) and finally to position (7, 8), set the size of the markers to 15,Set the color of all the edge DarkBlue and the face to Gold:**

# %%
xe = np.array([6,2,5,7])
ye = np.array([3,5,7,8])
plt.plot(xe, ye, marker = 'P',ms = 15, mec = '#00008B', mfc = '#FFD700')
plt.show()

# %% [markdown]
# **Or we can use any of the 140 supported color names.**

# %% [markdown]
# **Here's the list of 140 supported color names in Matplotlib:**
#
# *aliceblue, antiquewhite, aqua, aquamarine, azure, beige, bisque, black, blanchedalmond, blue, blueviolet, brown, burlywood, cadetblue, chartreuse, chocolate, coral, cornflowerblue, cornsilk, crimson, cyan, darkblue, darkcyan, darkgoldenrod, darkgray, darkgreen, darkkhaki, darkmagenta, darkolivegreen, darkorange, darkorchid, darkred, darksalmon, darkseagreen, darkslateblue, darkslategray, darkturquoise, darkviolet, deeppink, deepskyblue, dimgray, dodgerblue, firebrick, floralwhite, forestgreen, fuchsia, gainsboro, ghostwhite, gold, goldenrod, gray, green, greenyellow, honeydew, hotpink, indianred, indigo, ivory, khaki, lavender, lavenderblush, lawngreen, lemonchiffon, lightblue, lightcoral, lightcyan, lightgoldenrodyellow, lightgreen, lightgray, lightpink, lightsalmon, lightseagreen, lightskyblue, lightslategray, lightsteelblue, lightyellow, lime, limegreen, linen, magenta, maroon, mediumaquamarine, mediumblue, mediumorchid, mediumpurple, mediumseagreen, mediumslateblue, mediumspringgreen, mediumturquoise, mediumvioletred, midnightblue, mintcream, mistyrose, moccasin, navajowhite, navy, oldlace, olive, olivedrab, orange, orangered, orchid, palegoldenrod, palegreen, paleturquoise, palevioletred, papayawhip, peachpuff, peru, pink, plum, powderblue, purple, red, rosybrown, royalblue, saddlebrown, salmon, sandybrown, seagreen, seashell, sienna, silver, skyblue, slateblue, slategray, snow, springgreen, steelblue, tan, teal, thistle, tomato, turquoise, violet, wheat, white, whitesmoke, yellow, yellowgreen*

# %% [markdown]
# **Mark each point with the color named "indianred":**

# %%
xf = np.array([6,2,5,7])
yf = np.array([3,5,7,8])
plt.plot(xf, yf, marker = 'P',ms = 15, mec = 'indianred', mfc = 'indianred')
plt.show()

# %% [markdown]
# ## **Matplotlib Line**
# ### **Linestyle**
# We can use the keyword argument **linestyle**, or shorter **ls**, to change the style of the plotted line:

# %% [markdown]
# **We can choose any of these styles:**
#
# - 'solid' (default)	'-'
# - 'dotted'	':'
# - 'dashed'	'--'
# - 'dashdot'	'-.'
# - 'None'	'' or ' '

# %% [markdown]
# **Use a dotted line:**

# %%
yg = np.array([2,5,7,8,9,11])
plt.plot(yg, linestyle = 'dotted')
plt.show()

# %% [markdown]
# **Use a dashdot line:**

# %%
yh = np.array([2,5,7,8,9,11])
plt.plot(yh, linestyle = '-.')
plt.show()

# %% [markdown]
# ### **Line Color**
# You can use the keyword argument **color** or the shorter **c** to set the color of the line:

# %% [markdown]
# **Set the line color to 'indianred':**

# %%
yi = np.array([2,5,7,8,9,11])
plt.plot(yi, ls = '-.', color = 'indianred' )
plt.show()

# %% [markdown]
# ### **Line Width**
# You can use the keyword argument **linewidth** or the shorter **lw** to change the width of the line.
#
# The value is a floating number, in points:

# %% [markdown]
# **Plot with a 20.5pt wide line:**

# %%
yj = np.array([2,5,7,8,9,11])
plt.plot(yj, c = 'orangered', lw = '20.5'  )     # linestyle is default
plt.show()

# %% [markdown]
# ## **Multiple Lines**
# We can plot as many lines as you like by simply adding more **plt.plot()** functions:

# %% [markdown]
# **Draw two lines by specifying a plt.plot() function for each line:**

# %%
y1 = np.array([3,5,9,7,8,9,6])
y2 = np.array([6,2,6,11,7,4,9])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %% [markdown]
# We can also plot many lines by adding the points for the x- and y-axis for each line in the same **plt.plot()** function.
#
# The **x-** and **y-** values come in pairs:

# %% [markdown]
# **Draw two lines by specifiyng the x- and y-point values for both lines:**

# %%
xa1 = np.array([4,6,7,8])
ya1 = np.array([2,3,5,7])
xa2 = np.array([5,2,9,4])
ya2 = np.array([3,5,8,6])
plt.plot(xa1, ya1, xa2, ya2)
plt.show()

# %% [markdown]
# ## **Matplotlib Labels and Title**

# %% [markdown]
# Create Labels for a Plot
# With Pyplot, we can use the **xlabel()** and **ylabel()** functions to set a label for the x- and y-axis.

# %% [markdown]
# **Add labels to the x- and y-axis:**

# %%
year = np.array([2016,2017,2018,2019,2020,2021,2022,2023,2024])
sales = np.array([18000,19500,20000,25000,19000,30000,27000,29000,31000])


plt.xlabel("Year")
plt.ylabel("Total Sales")
plt.plot(year,sales)
plt.show()

# %% [markdown]
# ### **Create a Title for a Plot**
# With Pyplot, you can use the **title()** function to set a title for the plot.

# %% [markdown]
# Add a plot title and labels for the x- and y-axis:

# %%
year = np.array([2016,2017,2018,2019,2020,2021,2022,2023,2024])
sales = np.array([18000,19500,20000,25000,19000,30000,27000,29000,31000])

plt.xlabel("Year")
plt.ylabel("Total Sales")
plt.title("Sales by year")
plt.plot(year,sales)

plt.show()

# %% [markdown]
# ### **Set Font Properties for Title and Labels**
# You can use the **fontdict** parameter in **xlabel()**, **ylabel()**, and **title()** to set font properties for the title and labels.

# %%
year = np.array([2016,2017,2018,2019,2020,2021,2022,2023,2024])
sales = np.array([18000,19500,20000,25000,19000,30000,27000,29000,31000])

fonta = {'family':'Arial', 'color':'darkblue', 'size':25}
fontb = {'family':'Arial', 'color':'indianred', 'size':15}
plt.xlabel("Year",fontdict = fontb)
plt.ylabel("Total Sales",fontdict = fontb)
plt.title("Sales by year", fontdict = fonta)
plt.plot(year,sales)

plt.show()

# %% [markdown]
# ### **Position the Title**
# You can use the **loc** parameter in title() to position the title.
# Values are: '**left**', '**right**', and '**center**'. Default value is 'center'.

# %%
year = np.array([2016,2017,2018,2019,2020,2021,2022,2023,2024])
sales = np.array([18000,19500,20000,25000,19000,30000,27000,29000,31000])

fonta = {'family':'Arial', 'color':'darkblue', 'size':20}
fontb = {'family':'Arial', 'color':'indianred', 'size':15}
plt.xlabel("Year",fontdict = fontb)
plt.ylabel("Total Sales",fontdict = fontb)
plt.title("Sales by year", fontdict = fonta, loc = 'left')
plt.plot(year,sales)

plt.show()

# %% [markdown]
# ### **Add Grid Lines to a Plot**
# With Pyplot, you can use the **grid()** function to add grid lines to the plot.

# %% [markdown]
# **Add grid lines to the plot:**

# %%
year = np.array([2016,2017,2018,2019,2020,2021,2022,2023,2024])
sales = np.array([18000,19500,20000,25000,19000,30000,27000,29000,31000])

fonta = {'family':'Arial', 'color':'darkblue', 'size':20}
fontb = {'family':'Arial', 'color':'indianred', 'size':15}
plt.xlabel("Year",fontdict = fontb)
plt.ylabel("Total Sales",fontdict = fontb)
plt.title("Sales by year", fontdict = fonta)
plt.plot(year,sales)
plt.grid()
plt.show()

# %% [markdown]
# ### **Specify Which Grid Lines to Display**
# You can use the **axis** parameter in the grid() function to specify which grid lines to display.
#
# Legal values are: **'x'**, **'y'**, and 'both'. Default value is 'both'.

# %% [markdown]
# **Display only grid lines for the x-axis:**

# %%
year = np.array([2016,2017,2018,2019,2020,2021,2022,2023,2024])
sales = np.array([18000,19500,20000,25000,19000,30000,27000,29000,31000])

fonta = {'family':'Arial', 'color':'darkblue', 'size':20}
fontb = {'family':'Arial', 'color':'indianred', 'size':15}
plt.xlabel("Year",fontdict = fontb)
plt.ylabel("Total Sales",fontdict = fontb)
plt.title("Sales by year", fontdict = fonta)
plt.plot(year,sales)
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# **Display only grid lines for the y-axis:**

# %%
year = np.array([2016,2017,2018,2019,2020,2021,2022,2023,2024])
sales = np.array([18000,19500,20000,25000,19000,30000,27000,29000,31000])

fonta = {'family':'Arial', 'color':'darkblue', 'size':20}
fontb = {'family':'Arial', 'color':'indianred', 'size':15}
plt.xlabel("Year",fontdict = fontb)
plt.ylabel("Total Sales",fontdict = fontb)
plt.title("Sales by year", fontdict = fonta)
plt.plot(year,sales)
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# ### **Set Line Properties for the Grid**
# You can also set the line properties of the grid, like this: **grid(color = 'color', linestyle = 'linestyle', linewidth = number).**

# %%
year = np.array([2016,2017,2018,2019,2020,2021,2022,2023,2024])
sales = np.array([18000,19500,20000,25000,19000,30000,27000,29000,31000])

fonta = {'family':'Arial', 'color':'darkblue', 'size':20}
fontb = {'family':'Arial', 'color':'indianred', 'size':15}
plt.xlabel("Year",fontdict = fontb)
plt.ylabel("Total Sales",fontdict = fontb)
plt.title("Sales by year", fontdict = fonta)
plt.plot(year,sales)
plt.grid(axis = 'both', color = 'indianred', ls = ':', lw = 1 )
plt.show()

# %% [markdown]
# ## **Matplotlib Subplot**
# ### **Display Multiple Plots**
# **The subplot() Function-**
# The *subplot()* function takes three arguments that describes the layout of the figure.
#
# The layout is organized in *rows* and *columns*, which are represented by the *first* and *second* argument.
#
# The *third* argument represents the *index* of the current plot.

# %% [markdown]
# **Draw 2 plots on top of each other:**

# %%
#1st Plot
X1 = np.array([2,4,6,8])
Y1 = np.array([1,5,7,11])
plt.subplot(2,1,1)
plt.plot(X1,Y1)

#2nd Plot
X2 = np.array([3,4,7,9])
Y2 = np.array([2,4,5,8])
plt.subplot(2,1,2)
plt.plot(X2,Y2)

plt.show()

# %% [markdown]
# We can draw as many plots you like on one figure, just descibe the number of rows, columns, and the index of the plot.

# %% [markdown]
# **Draw 6 (2,3) plots in one diagram:**

# %%
#Plot 1
x1 = np.array([2,5,6,9])
y1 = np.array([1,3,4,6])
plt.subplot(2,3,1)
plt.plot(x1,y1)
#Plot 2
x2 = np.array([1,4,5,6])
y2 = np.array([2,6,8,9])
plt.subplot(2,3,2)
plt.plot(x2,y2)
#Plot 3
x3 = np.array([2,3,4,5])
y3 = np.array([1,5,7,8])
plt.subplot(2,3,3)
plt.plot(x3,y3)
#Plot 4
x4 = np.array([2,4,5,6])
y4 = np.array([2,5,7,9])
plt.subplot(2,3,4)
plt.plot(x4,y4)
#Plot 5
x5 = np.array([2,5,7,9])
y5 = np.array([3,5,6,9])
plt.subplot(2,3,5)
plt.plot(x5,y5)
#Plot 6
x6 = np.array([2,3,7,9])
y6 = np.array([4,6,8,9])
plt.subplot(2,3,6)
plt.plot(x6,y6)

plt.show()

# %% [markdown]
# ### **Title**
# You can add a title to each plot with the **title()** function:

# %% [markdown]
# **Draw 2 plots on top of each other:**

# %%
#1st Plot
X1_ = np.array([2,4,6,8])
Y1_ = np.array([1,5,7,11])
plt.subplot(1,2,1)
plt.plot(X1_,Y1_)
plt.title("Graph 1")

#2nd Plot
X2_ = np.array([3,4,7,9])
Y2_ = np.array([2,4,5,8])
plt.subplot(1,2,2)
plt.plot(X2_,Y2_)
plt.title("Graph 2")

plt.show()

# %% [markdown]
# ### **Super Title**
# You can add a title to the entire figure with the **suptitle()** function:

# %% [markdown]
# **Add a title for the entire figure:**

# %%
#1st Plot
X1_ = np.array([2,4,6,8])
Y1_ = np.array([1,5,7,11])
plt.subplot(1,2,1)
plt.plot(X1_,Y1_)
plt.title("Graph 1")

#2nd Plot
X2_ = np.array([3,4,7,9])
Y2_ = np.array([2,4,5,8])
plt.subplot(1,2,2)
plt.plot(X2_,Y2_)
plt.title("Graph 2")

plt.suptitle("Demo Graphs")
plt.show()

# %% [markdown]
# ### **Matplotlib Scatter**
# **Creating Scatter Plots**
# With Pyplot, we can use the **scatter()** function to draw a scatter plot.
#
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %% [markdown]
# **Create a simple scatter plot**

# %%
xs = np.array([2,5,7,9,11,8,13,12,6,11])
ys = np.array([25,27,35,28,37,29,33,32,28,30])

plt.scatter(xs,ys)
plt.show()

# %% [markdown]
# ## **Compare Plots**
# **Draw two plots on the same figure:**

# %%
#Plot1
xs1 = np.array([2,5,7,9,11,8,13,12,6,11])
ys1 = np.array([25,27,35,28,37,29,33,32,28,30])

plt.scatter(xs1,ys1)
#Plot2
xs2 = np.array([3,5,6,9,7,2,5,6,4,9])
ys2 = np.array([23,26,30,31,27,29,26,34,24,27])

plt.scatter(xs2,ys2)
#The two plots are plotted with two different colors, by default blue and orange
plt.show()

# %% [markdown]
# ### **Colors**
# You can set your own **color** for each scatter plot with the color or the **c** argument:

# %% [markdown]
# **Draw two plots on the same figure:**

# %%
#Plot1
xs1 = np.array([2,5,7,9,11,8,13,12,6,11])
ys1 = np.array([25,27,35,28,37,29,33,32,28,30])

plt.scatter(xs1,ys1, color = 'hotpink')
#Plot2
xs2 = np.array([3,5,6,9,7,2,5,6,4,9])
ys2 = np.array([23,26,30,31,27,29,26,34,24,27])

plt.scatter(xs2,ys2, color = 'darkgreen')
#The two plots are plotted with two different colors, by default blue and orange
plt.show()

# %% [markdown]
# ### **Color Each Dot**
# You can even set a specific color for each dot by using an array of colors as value for the c argument.
#
# ***Note: You cannot use the color argument for this, only the c argument.***

# %% [markdown]
# **Set your own color of the markers:**

# %%
xs = np.array([2,5,7,9,11,8,13,12,6,11])
ys = np.array([25,27,35,28,37,29,33,32,28,30])
colors = np.array(['gold', 'green', 'gray', 'pink', 'salmon', 'indianred', 'skyblue', 'gray', 'darkblue','yellow'])
plt.scatter(xs, ys, c = colors)
plt.show()

# %% [markdown]
# ## **Matplotlib Bars**
# ### **Creating Bars**
# With Pyplot, you can use the **bar()** function to draw bar graphs:

# %% [markdown]
# **Draw 4 bars:**

# %%
XB = np.array(['Arya','Vivek','Subhash','Tarun'])
YB = np.array([25,22,29,45])

plt.bar(XB, YB)
plt.show()

# %% [markdown]
# ### **Horizontal Bars**
# If you want the bars to be displayed horizontally instead of vertically, use the **barh()** function:

# %% [markdown]
# **Draw 4 horizontal bars:**

# %%
XB = np.array(['Arya','Vivek','Subhash','Tarun'])
YB = np.array([25,22,29,45])

plt.barh(XB, YB)
plt.show()

# %% [markdown]
# ### **Bar Color**
# The *bar()* and *barh()* take the keyword argument **color** to set the color of the bars:

# %% [markdown]
# **Draw 4 indianred bars:**

# %%
Xb1 = np.array(['Alto','Ritz','Nano','Santro'])
Yb1 = np.array([1200,950,1000,1400])
plt.title('Total Cars')
plt.xlabel('Car Name')
plt.ylabel('No.of cars')
plt.bar(Xb1, Yb1, color = 'indianred')
plt.show()

# %% [markdown]
# ### **Bar Width**
# The *bar()* takes the keyword argument width to set the **width** of the bars (default value of width is **0.8**):

# %% [markdown]
# **Draw 4 very thin bars:**

# %%
Xb1 = np.array(['Alto','Ritz','Nano','Santro'])
Yb1 = np.array([1200,950,1000,1400])
plt.title('Total Cars')
plt.xlabel('Car Name')
plt.ylabel('No.of cars')
plt.bar(Xb1, Yb1, color = 'indianred', width = 0.5)
plt.show()

# %% [markdown]
# ### **Bar Height**
# The *barh()* takes the keyword argument height to set the **height** of the bars (default value of height is **0.8**):

# %%
Xb1 = np.array(['Alto','Ritz','Nano','Santro'])
Yb1 = np.array([1200,950,1000,1400])
plt.title('Total Cars')
plt.ylabel('Car Name')
plt.xlabel('No.of cars')
plt.barh(Xb1, Yb1, color = 'indianred', height = 0.1)
plt.show()

# %% [markdown]
# ## **Matplotlib Pie Charts**
# ### **Creating Pie Charts**
# With Pyplot, we can use the **pie()** function to draw pie charts:

# %% [markdown]
# **A simple pie chart:**

# %%
yr = np.array([15,40,25,20])
plt.pie(yr)
plt.show()

# %% [markdown]
# As we can see the pie chart draws one piece (called a **wedge**) for each value in the array (in this case [15,40,25,20]).
#
# By default the plotting of the *first* wedge starts from the x-axis and moves *counterclockwise*:

# %% [markdown]
# **Note: The size of each wedge is determined by comparing the value with all the other values, by using this formula. The value divided by the sum of all values: x/sum(x)**

# %% [markdown]
# ### **Labels**
# Add labels to the pie chart with the **labels** parameter.
#
# The labels parameter must be an array with one label for each wedge:

# %%
yr = np.array([15,40,25,20])
l = np.array(['Others','Redmi','Apple','Samsung'])
plt.pie(yr, labels = l)
plt.show()

# %% [markdown]
# ### **Start Angle**
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a **startangle** parameter.
#
# The startangle parameter is defined with an angle in degrees, default angle is 0:

# %%
yr = np.array([15,40,25,20])
l = np.array(['Others','Redmi','Apple','Samsung'])
plt.pie(yr, labels = l, startangle = 90)
plt.show()

# %% [markdown]
# ### **Explode**
# Maybe you want one of the wedges to stand out? The **explode** parameter allows you to do that.
#
# The *explode* parameter, if specified, and not **None**, must be an array with one value for each wedge.
#
# Each value represents how far from the center each wedge is displayed:

# %% [markdown]
# **Pull the "Apples" wedge 0.2 from the center of the pie:**

# %%
yr = np.array([15,40,25,20])
l = np.array(['Others','Redmi','Apple','Samsung'])
e = np.array([0,0.1,0,0])
plt.pie(yr, labels = l, startangle = 90, explode = e)
plt.show()

# %% [markdown]
# ### **Shadow**
# Add a shadow to the pie chart by setting the **shadow** parameter to **True**:

# %%
yr = np.array([15,40,25,20])
l = np.array(['Others','Redmi','Apple','Samsung'])
e = np.array([0,0.1,0,0])
plt.pie(yr, labels = l, startangle = 90, explode = e, shadow = True)
plt.show()

# %% [markdown]
# ### **Colors**
# You can set the color of each wedge with the colors parameter.
#
# The **colors** parameter, if specified, must be an array with one value for each wedge:

# %%
yr = np.array([15,40,25,20])
l = np.array(['Others','Redmi','Apple','Samsung'])
c = np.array(['skyblue','gold','lightgreen','indianred']) 
e = np.array([0,0.1,0,0])
plt.pie(yr, labels = l, startangle = 90, explode = e, colors = c, shadow = True)
plt.show()

# %% [markdown]
# ### **Legend**
# To add a list of explanation for each wedge, use the **legend()** function:

# %%
yr = np.array([15,40,25,20])
l = np.array(['Others','Redmi','Apple','Samsung'])
c = np.array(['skyblue','gold','lightgreen','indianred']) 
e = np.array([0,0.1,0,0])
plt.pie(yr, labels = l, startangle = 90, explode = e, colors = c, shadow = True)
plt.legend()
plt.show()

# %% [markdown]
# ### **Legend With Header**
# To add a header to the legend, add the **title** parameter to the legend function.

# %%
yr = np.array([15,40,25,20])
l = np.array(['Others','Redmi','Apple','Samsung'])
c = np.array(['skyblue','gold','lightgreen','indianred']) 
e = np.array([0,0.1,0,0])
plt.pie(yr, labels = l, startangle = 90, explode = e, colors = c, shadow = True)
plt.legend(title = 'Mobile Brand')
plt.show()
